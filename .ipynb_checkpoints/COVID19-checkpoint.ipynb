# %%
import pandas as pd 
import numpy as np
import csv
import json
import requests
import urllib.request as downloader
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
import datetime


today = datetime.datetime.now()
try:
    print('Downloading Dataset')

    url = 'https://covid.ourworldindata.org/data/ecdc/full_data.csv'
    r = requests.get(url)

    with open('Data/full_data.csv', 'wb') as f:
        f.write(r.content)
        print('Done!')
        print('Build Date: %s'%today)
except e:
    print(e)
# Out:
# Downloading Dataset
# Done!
# Build Date: 2020-06-08 03:36:25.510461

# %%
database = pd.read_csv('Data/full_data.csv', sep=',')

# %%
database.head()
# Out:
#          date     location  new_cases  new_deaths  total_cases  total_deaths
# 0  2019-12-31  Afghanistan          0           0            0             0
# 1  2020-01-01  Afghanistan          0           0            0             0
# 2  2020-01-02  Afghanistan          0           0            0             0
# 3  2020-01-03  Afghanistan          0           0            0             0
# 4  2020-01-04  Afghanistan          0           0            0             0

# %%
database.columns
# Out:
# Index(['date', 'location', 'new_cases', 'new_deaths', 'total_cases',
#        'total_deaths'],
#       dtype='object')

# %%
database.query('location=="Brazil"')
# Out:
#             date location  new_cases  new_deaths  total_cases  total_deaths
# 2861  2019-12-31   Brazil          0           0            0             0
# 2862  2020-01-01   Brazil          0           0            0             0
# 2863  2020-01-02   Brazil          0           0            0             0
# 2864  2020-01-03   Brazil          0           0            0             0
# 2865  2020-01-04   Brazil          0           0            0             0
# 2866  2020-01-05   Brazil          0           0            0             0
# 2867  2020-01-06   Brazil          0           0            0             0
# 2868  2020-01-07   Brazil          0           0            0             0
# 2869  2020-01-08   Brazil          0           0            0             0
# 2870  2020-01-09   Brazil          0           0            0             0
# 2871  2020-01-10   Brazil          0           0            0             0
# 2872  2020-01-11   Brazil          0           0            0             0
# 2873  2020-01-12   Brazil          0           0            0             0
# 2874  2020-01-13   Brazil          0           0            0             0
# 2875  2020-01-14   Brazil          0           0            0             0
# 2876  2020-01-15   Brazil          0           0            0             0
# 2877  2020-01-16   Brazil          0           0            0             0
# 2878  2020-01-17   Brazil          0           0            0             0
# 2879  2020-01-18   Brazil          0           0            0             0
# 2880  2020-01-19   Brazil          0           0            0             0
# 2881  2020-01-20   Brazil          0           0            0             0
# 2882  2020-01-21   Brazil          0           0            0             0
# 2883  2020-01-22   Brazil          0           0            0             0
# 2884  2020-01-23   Brazil          0           0            0             0
# 2885  2020-01-24   Brazil          0           0            0             0
# 2886  2020-01-25   Brazil          0           0            0             0
# 2887  2020-01-26   Brazil          0           0            0             0
# 2888  2020-01-27   Brazil          0           0            0             0
# 2889  2020-01-28   Brazil          0           0            0             0
# 2890  2020-01-29   Brazil          0           0            0             0
# ...          ...      ...        ...         ...          ...           ...
# 2991  2020-05-09   Brazil      10222         751       145328          9897
# 2992  2020-05-10   Brazil      10611         730       155939         10627
# 2993  2020-05-11   Brazil       6760         496       162699         11123
# 2994  2020-05-12   Brazil       5632         396       168331         11519
# 2995  2020-05-13   Brazil       9258         881       177589         12400
# 2996  2020-05-14   Brazil      11385         749       188974         13149
# 2997  2020-05-15   Brazil      13944         844       202918         13993
# 2998  2020-05-16   Brazil      15305         824       218223         14817
# 2999  2020-05-17   Brazil      14919         816       233142         15633
# 3000  2020-05-18   Brazil       7938         485       241080         16118
# 3001  2020-05-19   Brazil      13140         674       254220         16792
# 3002  2020-05-20   Brazil      17408        1179       271628         17971
# 3003  2020-05-21   Brazil      19951         888       291579         18859
# 3004  2020-05-22   Brazil      18508        1188       310087         20047
# 3005  2020-05-23   Brazil      20803        1001       330890         21048
# 3006  2020-05-24   Brazil      16508         965       347398         22013
# 3007  2020-05-25   Brazil      15813         653       363211         22666
# 3008  2020-05-26   Brazil      11687         807       374898         23473
# 3009  2020-05-27   Brazil      16324        1039       391222         24512
# 3010  2020-05-28   Brazil      20599        1086       411821         25598
# 3011  2020-05-29   Brazil      26417        1156       438238         26754
# 3012  2020-05-30   Brazil      26928        1124       465166         27878
# 3013  2020-05-31   Brazil      33274         956       498440         28834
# 3014  2020-06-01   Brazil      16409         480       514849         29314
# 3015  2020-06-02   Brazil      11598         623       526447         29937
# 3016  2020-06-03   Brazil      28936        1262       555383         31199
# 3017  2020-06-04   Brazil      28633        1349       584016         32548
# 3018  2020-06-05   Brazil      30925        1473       614941         34021
# 3019  2020-06-06   Brazil          0           0       614941         34021
# 3020  2020-06-07   Brazil      30830        1005       645771         35026
#
# [160 rows x 6 columns]

# %%
brazilCases = database.query('location=="Brazil"')
# import matplotlib.pyplot as plt
# %matplotlib inline
# brazilCases['new_cases'].value_counts().head(10).plot(kind='bar')

# %%
# brazilCases['new_cases'].value_counts().sort_values().plot(kind='bar', figsize=(20,10), grid=True, rot=0)

# %%
database.query('location=="Brazil"').sort_values(by='date').plot()#kind='bar', figsize=(15,5))

# %%
brazilCases.sort_values(by="date")#kind='bar', figsize=(15,5))
# brazilCases.set_index("date",drop=True,inplace=True)

brazilCases.sort_values(by='date', ascending=False).head(14).plot(kind='bar', figsize=(17,10), x='date', rot=0)
plt.title('COVID-19 Brazil')
plt.ylabel('Quantity')
plt.xlabel('Date')

plt.savefig('Charts/BrazilCasesPerDay.png')

# %% [markdown]
# ## Charts COVID-19 Brazil
#
#     *New Deaths;
#     *New Cases;
#     *Total Cases;
#     *Total Deaths;

# %%
# total_deaths = brazilCases["total_deaths"].value_counts()
# total_deaths.groupby('total_deaths').plot(kind='barh', x='date', y='total_deaths')

brazilCases.groupby('new_deaths').head(14).plot(x='date', y='new_deaths', figsize=(15,10))
plt.title('New deaths COVID-19 - Brazil - 08/04/2020')
plt.ylabel('Quantity')
plt.xlabel('Date')
plt.savefig('Charts/New deaths COVID19Brazil02042020.png')

# %%
# total_deaths = brazilCases["total_deaths"].value_counts()
# total_deaths.groupby('total_deaths').plot(kind='barh', x='date', y='total_deaths')

brazilCases.groupby('new_cases').head(14).plot(x='date', y='new_cases', figsize=(15,10))
plt.title('New cases COVID-19 - Brazil - 08/04/2020')
plt.ylabel('Quantity')
plt.xlabel('Date')
plt.savefig('Charts/New cases COVID19Brazil02042020.png')

# %%
# total_deaths = brazilCases["total_deaths"].value_counts()
# total_deaths.groupby('total_deaths').plot(kind='barh', x='date', y='total_deaths')

brazilCases.groupby('total_cases').head(10).plot(x='date', y='total_cases', figsize=(17,10))
plt.title('Total cases COVID-19 - Brazil - 08/04/2020')
plt.ylabel('Quantity')
plt.xlabel('Date')
plt.savefig('Charts/Total cases COVID19Brazil02042020.png')

# %%
# total_deaths = brazilCases["total_deaths"].value_counts()
# total_deaths.groupby('total_deaths').plot(kind='barh', x='date', y='total_deaths')

brazilCases.groupby('total_deaths').head(14).plot(x='date', y='total_deaths', figsize=(15,10))
plt.title('Total deaths COVID-19 - Brazil - 08/04/2020')
plt.ylabel('Quantity')
plt.xlabel('Date')
plt.savefig('Charts/Total deaths COVID19Brazil02042020.png')

# %%
def plotChartTotalDeaths(countryData):
    countryData.groupby('total_deaths').head(10).plot(x='date', y='total_deaths', figsize=(15,10))
    plt.title('Total Deaths COVID-19 '+ countryData['location'].iloc[0])
    plt.ylabel('Quantity')
    plt.xlabel('Date')
    plt.savefig('Charts/TotalDeaths/%s - COVID19.png'%countryData['location'].iloc[0])
def plotChartTotalCases(countryData):
    countryData.groupby('total_cases').head(10).plot(x='date', y='total_cases', figsize=(15,10))
    plt.title('Total cases COVID-19 '+ countryData['location'].iloc[0])
    plt.ylabel('Quantity')
    plt.xlabel('Date')
    plt.savefig('Charts/TotalCases/%s - COVID19.png'%countryData['location'].iloc[0])
    
def plotChartNewCases(countryData):
    countryData.groupby('new_cases').head(10).plot(x='date', y='new_cases', figsize=(15,10))
    plt.title('New Cases COVID-19'+ countryData['location'].iloc[0]+'.png')
    plt.ylabel('Quantity')
    plt.xlabel('Date')
    plt.savefig('Charts/NewCases/%s - COVID19.png'%countryData['location'].iloc[0])

def plotChartNewDeaths(countryData):
    countryData.groupby('new_deaths').head(10).plot(x='date', y='new_deaths', figsize=(15,10))
    plt.title('New deaths COVID-19 ' + countryData['location'].iloc[0])
    plt.ylabel('Quantity')
    plt.xlabel('Date')
    plt.savefig('Charts/NewDeaths/%s - COVID19.png'%countryData['location'].iloc[0])

# %%
def plotDataByCountry(country):
    countryData = database.query('location=="%s"'%country)
    plotChartTotalDeaths(countryData)
    plotChartTotalCases(countryData)
    plotChartNewCases(countryData)
    plotChartNewDeaths(countryData)

# %%
plotDataByCountry('Brazil')
plotDataByCountry('Spain')
plotDataByCountry('Italy')
plotDataByCountry('United States')

# %%
brazilCases.head()
# Out:
#             date location  new_cases  new_deaths  total_cases  total_deaths
# 2861  2019-12-31   Brazil          0           0            0             0
# 2862  2020-01-01   Brazil          0           0            0             0
# 2863  2020-01-02   Brazil          0           0            0             0
# 2864  2020-01-03   Brazil          0           0            0             0
# 2865  2020-01-04   Brazil          0           0            0             0
